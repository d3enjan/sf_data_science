# %% [markdown]
# # <center> Home work

# %%
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt
from comet_ml import Experiment

# %%
from comet_ml import Experiment

# %%
# Создайте эксперимент с помощью вашего API ключа
experiment = Experiment(
    api_key='DyKCjbIHatbtKTHkQOitHuV0b',
    project_name='medical-appointment',
    workspace='d3enjan',
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.com/d3enjan/medical-appointment/49ee491eaf864851970823e74d89d356

# %%
df = pd.read_csv('data/KaggleV2-May-2016.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
# Выводи уникальные значения и смотрим на наличие аномалии.
print("Уникальные значения в `Age` => {}".format(df.Age.unique()))
# Out:
# Уникальные значения в `Age` => [ 62  56   8  76  23  39  21  19  30  29  22  28  54  15  50  40  46   4
#   13  65  45  51  32  12  61  38  79  18  63  64  85  59  55  71  49  78
#   31  58  27   6   2  11   7   0   3   1  69  68  60  67  36  10  35  20
#   26  34  33  16  42   5  47  17  41  44  37  24  66  77  81  70  53  75
#   73  52  74  43  89  57  14   9  48  83  72  25  80  87  88  84  82  90
#   94  86  91  98  92  96  93  95  97 102 115 100  99  -1]

# %%
# Удалим аномальные значения
df = df[(df.Age >= 0) & (df.Age <= 110)]
df.Age.value_counts()
# Out:
# 0      3539
# 1      2273
# 52     1746
# 49     1652
# 53     1651
#        ...
# 97       11
# 98        6
# 100       4
# 102       2
# 99        1
# Name: Age, Length: 102, dtype: int64

# %%
numeric_data = (['Gender', 'Neighbourhood','AppointmentID', 'PatientId', 'ScheduledDay', 'AppointmentDay', 'No-show'])
df.drop(numeric_data, axis=1, inplace = True)

# %%
plt.figure(figsize=(18,6))
sns.heatmap(df.corr(), annot=True)
experiment.log_figure(figure=plt)
# Out:
# {'web': 'https://www.comet.com/api/image/download?imageId=08ea1adcaf3d46bfb615e7b877f19021&experimentKey=49ee491eaf864851970823e74d89d356',
#  'api': 'https://www.comet.com/api/rest/v1/image/get-image?imageId=08ea1adcaf3d46bfb615e7b877f19021&experimentKey=49ee491eaf864851970823e74d89d356',
#  'imageId': '08ea1adcaf3d46bfb615e7b877f19021'}

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/d3enjan/medical-appointment/49ee491eaf864851970823e74d89d356
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     figures             : 1
# COMET INFO:     filename            : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     source_code         : 1
# COMET INFO: ---------------------------
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The Python SDK has 3600 seconds to finish before aborting...
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# ...
