# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
hh_data = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', sep=';')
hh_data.head()#
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\d3en\OneDrive\Рабочий стол\dataScience\IDE\PROJECT-1. Анализ вакансий из HeadHunter\Ноутбук решение.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/d3en/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/dataScience/IDE/PROJECT-1.%20%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%20%D0%B2%D0%B0%D0%BA%D0%B0%D0%BD%D1%81%D0%B8%D0%B9%20%D0%B8%D0%B7%20HeadHunter/%D0%9D%D0%BE%D1%83%D1%82%D0%B1%D1%83%D0%BA%20%D1%80%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D0%B5.ipynb#ch0000001?line=0'>1</a> hh_data = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', sep=';')
#       <a href='vscode-notebook-cell:/c%3A/Users/d3en/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/dataScience/IDE/PROJECT-1.%20%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%20%D0%B2%D0%B0%D0%BA%D0%B0%D0%BD%D1%81%D0%B8%D0%B9%20%D0%B8%D0%B7%20HeadHunter/%D0%9D%D0%BE%D1%83%D1%82%D0%B1%D1%83%D0%BA%20%D1%80%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D0%B5.ipynb#ch0000001?line=1'>2</a> hh_data.head()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=579'>580</a> with parser:
# --> <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=580'>581</a>     return parser.read(nrows)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1250, in TextFileReader.read(self, nrows)
#    <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=1247'>1248</a> nrows = validate_integer("nrows", nrows)
#    <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=1248'>1249</a> try:
# -> <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=1249'>1250</a>     index, columns, col_dict = self._engine.read(nrows)
#    <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=1250'>1251</a> except Exception:
#    <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/readers.py?line=1251'>1252</a>     self.close()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=222'>223</a> try:
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=223'>224</a>     if self.low_memory:
# --> <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=224'>225</a>         chunks = self._reader.read_low_memory(nrows)
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=225'>226</a>         # destructive to chunks
#     <a href='file:///c%3A/Users/d3en/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=226'>227</a>         data = _concatenate_chunks(chunks)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\parsers.pyx:883, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\parsers.pyx:1026, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\parsers.pyx:1072, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\parsers.pyx:1222, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\parsers.pyx:1235, in pandas._libs.parsers.TextReader._string_convert()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\parsers.pyx:1431, in pandas._libs.parsers._string_box_utf8()
#
# MemoryError:

# %%
hh_data.shape
# Out:
# (44744, 12)

# %%
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# dtypes: object(12)
# memory usage: 4.1+ MB

# %%
hh_data.isnull()
# Out:
#        Пол, возраст     ЗП  Ищет работу на должность:  \
# 0             False  False                      False
# 1             False  False                      False
# 2             False  False                      False
# 3             False  False                      False
# 4             False  False                      False
# ...             ...    ...                        ...
# 44739         False  False                      False
# 44740         False  False                      False
# 44741         False  False                      False
# 44742         False  False                      False
# 44743         False  False                      False
#
#        Город, переезд, командировки  Занятость  График  Опыт работы  \
# 0                             False      False   False        False
# 1                             False      False   False        False
# 2                             False      False   False        False
# 3                             False      False   False        False
# 4                             False      False   False        False
# ...                             ...        ...     ...          ...
# 44739                         False      False   False        False
# 44740                         False      False   False        False
# 44741                         False      False   False        False
# 44742                         False      False   False        False
# 44743                         False      False   False        False
#
#        Последнее/нынешнее место работы  Последняя/нынешняя должность  \
# 0                                False                         False
# 1                                False                         False
# 2                                False                         False
# 3                                False                         False
# 4                                False                         False
# ...                                ...                           ...
# 44739                            False                         False
# 44740                            False                         False
# 44741                            False                         False
# 44742                            False                         False
# 44743                            False                         False
#
#        Образование и ВУЗ  Обновление резюме   Авто
# 0                  False              False  False
# 1                  False              False  False
# 2                  False              False  False
# 3                  False              False  False
# 4                  False              False  False
# ...                  ...                ...    ...
# 44739              False              False  False
# 44740              False              False  False
# 44741              False              False  False
# 44742              False              False  False
# 44743              False              False  False
#
# [44744 rows x 12 columns]

# %%
hh_data.head(1)
# Out:
#                                  Пол, возраст          ЗП  \
# 0  Мужчина ,  39 лет , родился 27 ноября 1979  29000 руб.
#
#   Ищет работу на должность:  \
# 0   Системный администратор
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
#
#                                          Опыт работы  \
# 0  Опыт работы 16 лет 10 месяцев  Август 2010 — п...
#
#   Последнее/нынешнее место работы Последняя/нынешняя должность  \
# 0         МАОУ "СОШ № 1 г.Немана"      Системный администратор
#
#                                    Образование и ВУЗ Обновление резюме  \
# 0  Неоконченное высшее образование 2000  Балтийск...  16.04.2019 15:59
#
#                              Авто
# 0  Имеется собственный автомобиль

# %%
# Функция заменят в столбце Образование и ВУЗ, значение на ТОЛЬКО ОБРАЗОВАНИЕ, и создает новый столбец со значениями.


def get_education(level):
  
  education = ['Высшее', 'Неоконченное высшее', 'Среднее специальное', 'Среднее'] # Создаем список с уровнем образования
  education_new = ' '.join(level.split(' ')[:3]) # разбиваем значение признака "Образование и ВУЗ" на список слов
  
  if 'Высшее' in education_new:
    return education[0]
  elif 'Неоконченное высшее' in education_new:
    return education[1]
  elif 'специальное' in education_new:
    return education[2]
  elif 'Среднее' in education_new:
    return education[3]
  
  


# Функция выделяет из столбца "пол, возраст", возраст соискателя.
def Age(arg):
    arg_splitted = arg.split(' ')
    year=['год', 'года', 'лет']
    for index, item in enumerate (arg_splitted):
        if item in year:
            return int(arg_splitted[index-1])
          
hh_data['Образование'] = hh_data['Образование и ВУЗ'].apply(get_education) # Новый стобец "Образование"
print(hh_data['Образование'].value_counts()) # Узнаем ответ на вопрос "Сколько соискателей имеет средний уровень образования (школьное образование)?"
hh_data['Возраст'] = hh_data['Пол, возраст'].apply(Age)
hh_data = hh_data.drop('Образование и ВУЗ', axis= 1) # Удаляем столбец 'Образование и ВУЗ'
hh_data = hh_data.drop('Пол, возраст', axis= 1)
hh_data.head()
# Out:
# Высшее                 33863
# Среднее специальное     5765
# Неоконченное высшее     4557
# Среднее                  559
# Name: Образование, dtype: int64
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# 3  частичная занятость, проектная работа, полная ...
# 4                                   полная занятость
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
# 2                                        полный день
# 3                    гибкий график, удаленная работа
# 4                                        полный день
#
#                                          Опыт работы  \
# 0  Опыт работы 16 лет 10 месяцев  Август 2010 — п...
# 1  Опыт работы 19 лет 5 месяцев  Январь 2000 — по...
# 2  Опыт работы 10 лет 3 месяца  Октябрь 2004 — Де...
# 3  Опыт работы 18 лет 9 месяцев  Август 2017 — Ап...
# 4  Опыт работы 5 лет 7 месяцев  Региональный мене...
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# 1  Менеджер проекта, Аналитик, Технический писатель  12.04.2019 08:42
# 2                               Кассир-операционист  16.04.2019 08:35
# 3                               Инженер-программист  08.04.2019 14:23
# 4                              Менеджер по продажам  22.04.2019 10:32
#
#                              Авто          Образование  Возраст
# 0  Имеется собственный автомобиль  Неоконченное высшее       39
# 1                      Не указано               Высшее       60
# 2                      Не указано  Среднее специальное       36
# 3                      Не указано               Высшее       38
# 4                      Не указано               Высшее       26
